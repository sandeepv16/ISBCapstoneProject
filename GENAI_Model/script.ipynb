# %%
import torch
import cv2
from ultralytics import YOLO
import numpy as np

def count_pipes(model_path, image_path):
    """
    Detect and count pipes of different shapes using a trained YOLO model
    
    Args:
        model_path (str): Path to the trained YOLO model (.pt file)
        image_path (str): Path to the input image
    
    Returns:
        dict: Counts of pipes for each shape
    """
    # Load the trained YOLO model
    model = YOLO(model_path)
    
    # Perform inference
    results = model(image_path)
    
    # Initialize shape counters
    shape_counts = {
        'circular': 0,
        'rectangular': 0, 
        'square': 0,
        'hexagonal': 0
    }
    
    # Process detection results
    for result in results:
        # Get bounding boxes, classes, and confidence scores
        boxes = result.boxes
        
        for box in boxes:
            # Get the detected class
            cls = result.names[int(box.cls[0])]
            
            # Count pipes by shape
            if cls.lower() in shape_counts:
                shape_counts[cls.lower()] += 1
    
    return shape_counts

def visualize_detections(model_path, image_path, output_path=None):
    """
    Visualize pipe detections on the image
    
    Args:
        model_path (str): Path to the trained YOLO model (.pt file)
        image_path (str): Path to the input image
        output_path (str, optional): Path to save the annotated image
    
    Returns:
        numpy.ndarray: Image with detections annotated
    """
    # Load the trained YOLO model
    model = YOLO(model_path)
    
    # Read the image
    image = cv2.imread(image_path)
    
    # Perform inference
    results = model(image_path)
    
    # Annotate the image
    annotated_image = results[0].plot()
    
    # Save the annotated image if output path is provided
    if output_path:
        cv2.imwrite(output_path, annotated_image)
    
    return annotated_image

# Example usage
if __name__ == "__main__":
    # Path to your trained model
    model_path = 'best.pt'
    
    # Path to the input image
    image_path = r"uploaded_images\uploaded_image_20241207_165753.jpg"
    
    # Count pipes
    pipe_counts = count_pipes(model_path, image_path)
    print("Pipe Counts:")
    for shape, count in pipe_counts.items():
        print(f"{shape.capitalize()} Pipes: {count}")
    
    # Visualize detections
    output_image_path = 'detected_pipes.jpg'
    visualize_detections(model_path, image_path, output_image_path)
    print(f"Annotated image saved to {output_image_path}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 85
#      82 image_path = r"uploaded_images\uploaded_image_20241207_165753.jpg"
#      84 # Count pipes
# ---> 85 pipe_counts = count_pipes(model_path, image_path)
#      86 print("Pipe Counts:")
#      87 for shape, count in pipe_counts.items():
#
# Cell In[2], line 21, in count_pipes(model_path, image_path)
#      18 model = YOLO(model_path)
#      20 # Perform inference
# ---> 21 results = model(image_path)
#      23 # Initialize shape counters
#      24 shape_counts = {
#      25     'circular': 0,
#      26     'rectangular': 0,
#      27     'square': 0,
#      28     'hexagonal': 0
#      29 }
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\model.py:176, in Model.__call__(self, source, stream, **kwargs)
#     147 def __call__(
#     148     self,
#     149     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     150     stream: bool = False,
#     151     **kwargs,
#     152 ) -> list:
#     153     """
#     154     Alias for the predict method, enabling the model instance to be callable for predictions.
#     155
#    (...)
#     174         ...     print(f"Detected {len(r)} objects in image")
#     175     """
# --> 176     return self.predict(source, stream, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\model.py:554, in Model.predict(self, source, stream, predictor, **kwargs)
#     552 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     553     self.predictor.set_prompts(prompts)
# --> 554 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:234, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     232 # Warmup model
#     233 if not self.done_warmup:
# --> 234     self.model.warmup(imgsz=(1 if self.model.pt or self.model.triton else self.dataset.bs, 3, *self.imgsz))
#     235     self.done_warmup = True
#     237 self.seen, self.windows, self.batch = 0, [], None
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\autobackend.py:642, in AutoBackend.warmup(self, imgsz)
#     635 def warmup(self, imgsz=(1, 3, 640, 640)):
#     636     """
#     637     Warm up the model by running one forward pass with a dummy input.
#     638
#     639     Args:
#     640         imgsz (tuple): The shape of the dummy input tensor in the format (batch_size, channels, height, width)
#     641     """
# --> 642     import torchvision  # noqa (import here so torchvision import time not recorded in postprocess time)
#     644     warmup_types = self.pt, self.jit, self.onnx, self.engine, self.saved_model, self.pb, self.triton, self.nn_module
#     645     if any(warmup_types) and (self.device.type != "cpu" or self.triton):
#
# File ~\anaconda3\Lib\site-packages\torchvision\__init__.py:6
#       3 from modulefinder import Module
#       5 import torch
# ----> 6 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils
#       8 from .extension import _HAS_OPS
#      10 try:
#
# File ~\anaconda3\Lib\site-packages\torchvision\_meta_registrations.py:163
#     153     torch._check(
#     154         grad.dtype == rois.dtype,
#     155         lambda: (
#    (...)
#     158         ),
#     159     )
#     160     return grad.new_empty((batch_size, channels, height, width))
# --> 163 @torch._custom_ops.impl_abstract("torchvision::nms")
#     164 def meta_nms(dets, scores, iou_threshold):
#     165     torch._check(dets.dim() == 2, lambda: f"boxes should be a 2d tensor, got {dets.dim()}D")
#     166     torch._check(dets.size(1) == 4, lambda: f"boxes should have 4 elements in dimension 1, got {dets.size(1)}")
#
# File ~\anaconda3\Lib\site-packages\torch\library.py:795, in register_fake.<locals>.register(func)
#     793 else:
#     794     use_lib = lib
# --> 795 use_lib._register_fake(op_name, func, _stacklevel=stacklevel + 1)
#     796 return func
#
# File ~\anaconda3\Lib\site-packages\torch\library.py:184, in Library._register_fake(self, op_name, fn, _stacklevel)
#     181 else:
#     182     func_to_register = fn
# --> 184 handle = entry.fake_impl.register(func_to_register, source)
#     185 self._registration_handles.append(handle)
#
# File ~\anaconda3\Lib\site-packages\torch\_library\fake_impl.py:31, in FakeImplHolder.register(self, func, source)
#      25 if self.kernel is not None:
#      26     raise RuntimeError(
#      27         f"register_fake(...): the operator {self.qualname} "
#      28         f"already has an fake impl registered at "
#      29         f"{self.kernel.source}."
#      30     )
# ---> 31 if torch._C._dispatch_has_kernel_for_dispatch_key(self.qualname, "Meta"):
#      32     raise RuntimeError(
#      33         f"register_fake(...): the operator {self.qualname} "
#      34         f"already has an DispatchKey::Meta implementation via a "
#    (...)
#      37         f"register_fake."
#      38     )
#      40 if torch._C._dispatch_has_kernel_for_dispatch_key(
#      41     self.qualname, "CompositeImplicitAutograd"
#      42 ):
#
# RuntimeError: operator torchvision::nms does not exist

# %%
pip install ultralytics
# Out:
# Looking in indexes: http://artifactory.uber.internal:4587/artifactory/api/pypi/pypi/simple/, https://pypi.org/simple
# Collecting ultralytics
#   Downloading ultralytics-8.3.48-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from ultralytics) (1.24.2)
# Collecting matplotlib>=3.3.0 (from ultralytics)
#   Downloading matplotlib-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: opencv-python>=4.6.0 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from ultralytics) (4.10.0.84)
# Collecting pillow>=7.1.2 (from ultralytics)
#   Downloading pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from ultralytics) (2.31.0)
# Collecting scipy>=1.4.1 (from ultralytics)
#   Downloading scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.0 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from ultralytics) (2.5.1)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.20.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.1 kB)
# Collecting tqdm>=4.64.0 (from ultralytics)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from ultralytics) (5.9.5)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Requirement already satisfied: pandas>=1.1.4 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from ultralytics) (1.5.0)
# Collecting seaborn>=0.11.0 (from ultralytics)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.13-py3-none-any.whl.metadata (9.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.3.0->ultralytics)
#   Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.3.0->ultralytics)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.3.0->ultralytics)
#   Downloading fonttools-4.55.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.0/165.0 kB 6.5 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.3.0->ultralytics)
#   Downloading kiwisolver-1.4.7-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2022.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.17)
# Requirement already satisfied: certifi>=2017.4.17 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.8.0)
# Requirement already satisfied: networkx in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /dsw/snapshots/1b75112a-85fa-4b13-9c56-5822402b8861/python310/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Downloading ultralytics-8.3.48-py3-none-any.whl (898 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.8/898.8 kB 19.8 MB/s eta 0:00:00a 0:00:01
# Downloading matplotlib-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 99.5 MB/s eta 0:00:00ta 0:00:01
# Downloading pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 118.9 MB/s eta 0:00:0000:01
# Downloading scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 78.7 MB/s eta 0:00:00:00:0100:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 94.8 MB/s eta 0:00:00
# Downloading torchvision-0.20.1-cp310-cp310-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 116.0 MB/s eta 0:00:00a 0:00:01
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 35.0 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.13-py3-none-any.whl (26 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (324 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 kB 102.5 MB/s eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 125.4 MB/s eta 0:00:0000:01
# Downloading kiwisolver-1.4.7-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 176.7 MB/s eta 0:00:00
# Installing collected packages: py-cpuinfo, tqdm, scipy, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn, ultralytics-thop, torchvision, ultralytics
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.2 kiwisolver-1.4.7 matplotlib-3.9.3 pillow-11.0.0 py-cpuinfo-9.0.0 scipy-1.14.1 seaborn-0.13.2 torchvision-0.20.1 tqdm-4.67.1 ultralytics-8.3.48 ultralytics-thop-2.0.13
# Note: you may need to restart the kernel to use updated packages.
